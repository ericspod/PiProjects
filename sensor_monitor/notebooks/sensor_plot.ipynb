# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("sensors.csv", parse_dates=['time'], index_col=['time'])
# df["time"]=pd.to_datetime(df["time"])
# df=df.set_index('time')

df
# Out:
#                             temperature  pressure  humidity  gas_resistance  \
# time
# 2022-08-20 18:36:18.462794    24.214500   1016.86    43.228    6.012918e+05
# 2022-08-20 18:36:28.462931    24.157167   1016.86    42.171    5.654335e+05
# 2022-08-20 18:36:38.463434    24.172250   1016.87    41.473    5.473009e+05
# 2022-08-20 18:36:48.473109    24.208800   1016.88    40.896    5.425166e+05
# 2022-08-20 18:36:58.482842    24.227417   1016.88    40.375    5.361257e+05
# ...                                 ...       ...       ...             ...
# 2022-08-20 21:01:41.147472    19.583300   1017.61    43.669    1.166619e+06
# 2022-08-20 21:01:51.157134    19.570800   1017.56    43.614    1.165623e+06
# 2022-08-20 21:02:01.166757    19.584250   1017.57    43.687    1.169617e+06
# 2022-08-20 21:02:11.176415    19.584250   1017.56    43.716    1.169617e+06
# 2022-08-20 21:02:21.186055    19.623650   1017.61    43.724    1.167617e+06
#
# ...

# %%
n=pd.Series(df.index).diff().to_numpy().astype(np.float32)
n[0]=0
n/=1e6

df["time_delta"]=n

# %%
ax1=df["c"].plot(figsize=(14,6))
ax2=ax1.twinx()
df["gas_resistance"].plot(ax=ax2,color='r')
df["reducing"].plot(ax=ax1.twinx(),color='g')
# df["time_delta"].plot(ax=ax2,color='g')
# Out:
# <AxesSubplot:xlabel='time'>
